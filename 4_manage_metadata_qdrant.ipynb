# %% [markdown]
# ## Create an Excel of unqiue records from Qdrant
# ### To generate the Excel file in this notebook's directory:
# 1. Choose local or cloud
# 2. Select the qdrant collection name
# 3. Click `Run All` in the notebook

# %% [markdown]
# ## 0. Imports and Configs

# %%
# %pip install qdrant_client -q --upgrade

# %%
import os


# Config Qdrant``
QDRANT_URL = os.getenv("QDRANT_URL")
QDRANT_API_KEY = os.getenv("QDRANT_API_KEY")
# QDRANT_URL = st.secrets["QDRANT_URL"]
# QDRANT_API_KEY = st.secrets["QDRANT_API_KEY"]
QDRANT_PATH = "/Users/drew_wilkins/Drews_Files/Drew/Python/Localcode/Drews_Tools/qdrant_ASK_lib_tools/qdrant_db"


# Configure access to push changes to Github
GITHUB_ACCESS_TOKEN_ASK_LIBRARYCATALOG = os.getenv(
    "GITHUB_ACCESS_TOKEN_ASK_LIBRARYCATALOG")

# %% [markdown]
# ## 1. Choose Local or Cloud

# %%
from qdrant_client import QdrantClient
import library_utils as lib

# Your choice of parameters here affects the rest of the notebook.
# If you change it here, be sure to click through the rest of the cells
# to reset the variables

client = QdrantClient(
    url=QDRANT_URL,  # for cloud
    api_key=QDRANT_API_KEY,  # for cloud
    # path=QDRANT_PATH,  # for local
)


lib.which_qdrant(client)
lib.list_collections(client)
# Out:
# qdrant location: cloud
#
# collections:
# ASK_vectorstore
# ask_pdf_docs
# ASK_vectorstore-backup21APR2025
# ask_pdf_pages

# %% [markdown]
# ## 2. Select the Qdrant collection

# %%
collection_name = "ASK_vectorstore"

# %%
from qdrant_client.http import models

records = client.scroll(
    collection_name=collection_name,
    with_payload=True,  # change to True to see the payload
    with_vectors=False,  # change to True to see the vectors
    limit=100000,  # 👈 don't forget to set this

    scroll_filter=models.Filter(
        must=[
            models.FieldCondition(
                key="metadata.scope",
                match=models.MatchText(
                    text="national"),
            ),
        ]
    ),
)

print(f"Number of points found: {len(records[0])}")
# Out:
# Number of points found: 11609

# %%
records[0][0]
# Out:
# Record(id='00043af2-745b-4672-b128-98e122e66eb8', payload={'page_content': 'May 2014  \nE. Implement FAA air space closure and air space de-\nconfliction plans to conduct operations as required.  \nF. Oversee creation of air task orders or flight schedules to \nmitigate safety risk of aircraft operations in confined or \nsaturated air space.  \nG. Coordinate airspace use with the FAA.  \nH. Request declaration or cancellation of Temporary Flight Restrictions (TFRs) in accordance with applicable \nFederal Aviat ion Regulations and post Notice to Airmen \n(NOTAM).  \nI. Attend the Tactics and Planning Meetings  to exchange \ninformation for development of  the Air Operations \nSummary (ICS 220- CG) and to confirm the number and \ntype of aircraft needed for the next operational period.  \nJ. Participate in preparation of the IAP through the OSC , \nensuring that the air operations portion includes  the Air \nTraffic Control (ATC) requirements of assigned aircraft.  \nK. Coordinate with the COML to designate air tactical and \nsupport frequencies.  \nL. Ensure reliable communication between the Air \nOperations Branch and air units.  \nM. Perform operational planning for air operations including \nemergency evacuation procedures of injured responders.  \nN. Prepare the Air Operations Summary (ICS 220 -CG), and \nprovide the summary along with incident maps and \ncopies of the IAP to the Air Support Group and Fixed -\nWing Bases.  \nO. Develop an aviation site safety plan in coordination with \nSOFR.  \nP. Consider requesting an ASOF  with aviation safety \ncertifications to work within the Air Operations Branch as \na THSP or for the SOFR.  \nQ. Report safety concerns, special incidents , and accidents \nto the SOFR.  \nR. Evaluate helibase and helispot locations.  \n7-11 \nOPERATIONS SECTION', 'metadata': {'publication_number': 'COMDTPUB P3120.17B', 'page': 83, 'source': './raw_pdfs/USCG Incident Mgmt Handbook COMDTPUB_P3120.17B_2014-05-01.pdf', 'page_count': 382, 'issue_date': '2014-05-22T00:00:00Z', 'upsert_date': '2024-12-18T23:28:56Z', 'pdf_id': '4cd5a55c-f37b-5c5d-b13d-b34d0a523051', 'aux_specific': False, 'scope': '1_national', 'unit': '', 'organization': 'CG-5RI', 'embedding': 'text-embedding-ada-002', 'public_release': True, 'title': 'U.S. Coast Guard Incident Management Handbook: Incident Command System (ICS), COMDTPUB P3120.17B', 'expiration_date': '2024-05-21T00:00:00Z'}}, vector=None, shard_key=None, order_value=None)

# %% [markdown]
# ## 3. Add a field to  the metadata

# %%
from collections import OrderedDict
import time
from qdrant_client import QdrantClient, models


def update_payload_with_unit_in_batches(
    client: QdrantClient,
    collection_name: str,
    default_unit_value: str = "",
    batch_size: int = 1000,
    scroll_timeout: int = 30
) -> None:
    """
    Update every record in the collection by adding a new metadata field 'unit'
    inserted immediately after the 'scope' field by updating only the payload.
    The records are processed in batches using client.batch_update_points.

    Parameters:
      - client: A QdrantClient instance.
      - collection_name: The name of the Qdrant collection.
      - default_unit_value: The default value to assign to the new 'unit' field.
      - batch_size: How many records to process per batch.
      - scroll_timeout: Timeout (in seconds) for each scroll call.
    """
    total_updated = 0

    while True:
        # Retrieve a batch of records (payload only).
        records = client.scroll(
            collection_name=collection_name,
            with_payload=True,
            with_vectors=False,
            limit=batch_size,
            offset=None,
            timeout=scroll_timeout
        )

        if not records:
            break

        update_ops = []
        for record in records:
            # Retrieve the original metadata (assumed to be a dictionary).
            metadata = record.payload.get("metadata", {})
            # Reconstruct metadata as an OrderedDict to enforce ordering.
            new_metadata = OrderedDict()
            inserted = False
            for key, value in metadata.items():
                new_metadata[key] = value
                if key == "scope":
                    # Insert the new "unit" field immediately after "scope"
                    new_metadata["unit"] = default_unit_value
                    inserted = True
            if not inserted:
                # If "scope" wasn't found, simply append "unit" at the end.
                new_metadata["unit"] = default_unit_value

            # Create a SetPayloadOperation with the correct syntax.
            update_ops.append(
                models.SetPayloadOperation(
                    set_payload=models.SetPayload(
                        payload={"metadata": new_metadata},
                        points=[record.id],
                    )
                )
            )

        if update_ops:
            # Use batch_update_points to update the payloads in this batch.
            client.batch_update_points(
                collection_name=collection_name,
                update_operations=update_ops
            )
            total_updated += len(update_ops)
            print(f"Updated {total_updated} records so far.")

        if next_page_offset is None:
            break

        time.sleep(0.5)  # Optional delay to reduce load

    print(
        f"Completed updating records. Total records updated: {total_updated}")


# Example usage:
# client = QdrantClient(url="your_qdrant_url", api_key="your_api_key")
# collection_name = "ASK_vectorstore"
update_payload_with_unit_in_batches(
    client, collection_name, default_unit_value="")

# %% [markdown]
# ## 4. Modify a metadata field

# %% [markdown]
# Example 1: populate missing expiration date

# %%
from qdrant_client.http.models import SetPayload, SetPayloadOperation
import time
import pandas as pd  # for isna() handling

DEFAULT_EXPIRATION = "2099-12-31T00:00:00Z"


def populate_missing_expiration():
    batch_size = 1000
    scroll_offset = None
    scroll_timeout = 30
    total_updated = 0

    while True:
        records, scroll_offset = client.scroll(
            collection_name=collection_name,
            with_payload=True,
            with_vectors=False,
            limit=batch_size,
            offset=scroll_offset,
            timeout=scroll_timeout
        )

        if not records:
            break

        update_ops = []

        for record in records:
            metadata = record.payload.get("metadata", {})
            current_value = metadata.get("expiration_date", None)

            if pd.isna(current_value) or current_value in ("", None):
                metadata["expiration_date"] = DEFAULT_EXPIRATION
                update_ops.append(
                    SetPayloadOperation(
                        set_payload=SetPayload(
                            payload={"metadata": metadata},
                            points=[record.id],
                        )
                    )
                )
                print(f"🔄 Set default expiration_date for record {record.id}")

        if update_ops:
            client.batch_update_points(
                collection_name=collection_name,
                update_operations=update_ops
            )
            total_updated += len(update_ops)
            print(f"✅ Updated {total_updated} records so far.")

        if scroll_offset is None:
            break

        time.sleep(0.5)

    print(f"🎉 Modification complete. Total records updated: {total_updated}")


# Run the migration
populate_missing_expiration()

# %% [markdown]
# Example 2: change text

# %%
from qdrant_client.http.models import PointStruct, SetPayload, SetPayloadOperation
from collections import OrderedDict
from dateutil import parser
from typing import Optional
import time


def convert_metadata_fields(metadata: dict, record_id: str) -> Optional[dict]:
    updated_metadata = OrderedDict()
    updated = False

    for key, value in metadata.items():
        if key == "scope" and value == "1_national":
            updated_metadata[key] = "national"
            updated = True
        else:
            updated_metadata[key] = value

    return updated_metadata if updated else None


def migrate_collection():
    batch_size = 1000
    scroll_offset = None
    scroll_timeout = 30
    total_updated = 0

    while True:
        records, scroll_offset = client.scroll(
            collection_name=collection_name,
            with_payload=True,
            with_vectors=False,
            limit=batch_size,
            offset=scroll_offset,
            timeout=scroll_timeout
        )

        if not records:
            break

        update_ops = []

        for record in records:
            metadata = record.payload.get("metadata", {})
            try:
                updated_metadata = convert_metadata_fields(
                    metadata, str(record.id))

                if updated_metadata:
                    print(f"🔄 Updating record {record.id}")
                    update_ops.append(
                        SetPayloadOperation(
                            set_payload=SetPayload(
                                payload={"metadata": updated_metadata},
                                points=[record.id],
                            )
                        )
                    )
            except Exception as e:
                print(f"❌ Exception while processing record {record.id}: {e}")

        if update_ops:
            client.batch_update_points(
                collection_name=collection_name,
                update_operations=update_ops
            )
            total_updated += len(update_ops)
            print(f"✅ Updated {total_updated} records so far.")

        if scroll_offset is None:
            break

        time.sleep(0.5)

    print(f"🎉 Migration complete. Total records updated: {total_updated}")


migrate_collection()
# Out:
# 🔄 Updating record 00043af2-745b-4672-b128-98e122e66eb8
# 🔄 Updating record 000bdeac-dc0f-4bdf-84a7-d4adaa4cb327
# 🔄 Updating record 000ee01d-2811-4500-b847-ac8486430938
# 🔄 Updating record 000f377e-8aa9-4f4d-ae0d-725215542ed3
# 🔄 Updating record 079f5a6e-8a6b-4367-b63c-2c1c6c2259ce
# 🔄 Updating record 07a10fd6-2ec6-4564-8fe0-f7a1290c58f2
# 🔄 Updating record 07a1b8e5-16dc-4837-a820-2d361b86dd25
# 🔄 Updating record 07b6e9c7-f0b6-4dfd-9423-ed7f5e95b5e3
# 🔄 Updating record 07bbfdac-ed57-47ee-a63b-fcf8b543e4ee
# 🔄 Updating record 07bd77b5-296e-4277-8ed0-ad46876d8f4b
# 🔄 Updating record 07bd80f0-aa92-449b-bd2c-5d7eb24e516f
# 🔄 Updating record 07c4e273-9f39-48ca-a87d-e44891647780
# 🔄 Updating record 07cbdbc7-a291-4ac9-a34d-17d1e25ef02c
# 🔄 Updating record 07cd7df3-e616-4450-8c05-1aabbb3a5d0c
# 🔄 Updating record 07cf30c9-f2c6-4569-9ca8-463bc62af106
# 🔄 Updating record 07d6228d-925a-4afe-bbcf-e72c62adc343
# 🔄 Updating record 07db4966-8ddb-4f1b-a900-5c104d9e5b6f
# 🔄 Updating record 07e26438-ba01-4b2d-9c03-9791a2d9adbd
# 🔄 Updating record 07ec9add-6996-4d84-bcfc-695d1057a69d
# 🔄 Updating record 07ed0263-9d79-4c05-88a2-e5f96ddea97f
# 🔄 Updating record 07fac0f0-da34-4911-a33c-72f5d102a689
# 🔄 Updating record 07fe5220-a19d-4378-9345-140343e9da47
# 🔄 Updating record 0802b161-6adb-4b2e-8016-8daf8bf7cb0e
# 🔄 Updating record 081baf52-7d06-4a37-a088-4dbd317176cc
# 🔄 Updating record 082245a6-63e9-4c2c-a4f9-0d39b578dc94
# 🔄 Updating record 0831ff71-c4a7-4b72-b32b-97447ef633d8
# 🔄 Updating record 0840917e-5090-4334-b099-d9fbd66744b5
# 🔄 Updating record 08445b24-51e2-43ab-9759-35e09f47f887
# 🔄 Updating record 084a5a0d-fb71-4993-99cf-d84547e619fa
# 🔄 Updating record 0853741d-d3b2-4a94-b594-19c85c95ad64
# 🔄 Updating record 08558335-b9e6-466c-89a4-02c4fa76aad3
# 🔄 Updating record 0856a739-f6c6-48c8-a170-813c808d4d7a
# 🔄 Updating record 08697804-d03b-45c0-98d6-a4c5a30b5ca8
# 🔄 Updating record 086db20e-7fb3-4482-9a19-ccb6cc75878d
# 🔄 Updating record 08828fef-c2a3-48f1-a8fb-116a7b6a92c2
# 🔄 Updating record 0893126a-f0cb-457b-b21f-9bea6b3646f5
# 🔄 Updating record 089345c6-c145-4c41-bece-3094e35da362
# 🔄 Updating record 0897290f-fafd-4921-8f84-20d0d00f88ff
# 🔄 Updating record 089ca673-c379-41d0-b32d-86a67a06917d
# 🔄 Updating record 08a261e4-40e9-4887-b8d5-3af53ac4e98e
# 🔄 Updating record 08a49ee5-8abd-444a-8efd-4021eb6f4a9d
# 🔄 Updating record 08a9a469-d696-4c9b-977a-e4ea1dc7df52
# 🔄 Updating record 08ae4064-a99d-43e3-b664-2e349d01ddc8
# 🔄 Updating record 08b1ab3b-f855-42d8-ac8c-bbfac0198a24
# 🔄 Updating record 0e800d85-09b7-4c65-8ffd-c1e0570e6dc5
# 🔄 Updating record 0e889487-01b6-41cb-af2d-baafcc77a62e
# 🔄 Updating record 0e8c3393-cff3-46d0-a52c-760b6a98e663
# 🔄 Updating record 0e9eee54-6922-480f-8fb8-168803107e0b
# 🔄 Updating record 0eae5453-74be-45d2-8061-66987a234096
# 🔄 Updating record 0eb5eb80-a4e3-4c36-be05-06b25169f6ea
# 🔄 Updating record 0eb82564-1db2-4e4f-b231-4d5b6940e75a
# 🔄 Updating record 0ec4da45-6db7-4a9d-b4db-c844d67eb745
# 🔄 Updating record 0ec998bb-9e8c-4b41-a929-3eaa39251da2
# 🔄 Updating record 0ed38635-51ce-4073-808f-c28711753ad6
# 🔄 Updating record 0ed76b36-82ed-4d1a-8855-a0c0298f7a95
# 🔄 Updating record 0ee0763d-2c93-463c-906b-87f8c23d9fa8
# 🔄 Updating record 0ee0a609-c837-4f91-b687-caabc749ae43
# 🔄 Updating record 0ee6e958-864e-45da-98c5-aa50086cea4e
# 🔄 Updating record 0ee7dabd-0e2b-4e16-b127-bcbe6e409112
# 🔄 Updating record 0ef57e97-bd05-4b4f-aec7-7dab73eb8f7f
# 🔄 Updating record 0ef96fcc-b5a5-448e-a24c-8bbe99333568
# 🔄 Updating record 0f03dfea-928c-4443-80ba-6c11f4aaeda9
# 🔄 Updating record 0f0552ea-c5c0-4a60-8387-1d3530ffdbec
# 🔄 Updating record 0f05a55a-e774-4b8d-85b4-06626f3f8dfb
# 🔄 Updating record 0f17dcf8-cd1e-488a-b89f-b1d3f4045c8b
# 🔄 Updating record 0f1b2103-348b-4ca3-8b4f-8115262c8f57
# 🔄 Updating record 0f20e109-97d6-4328-86fa-476a3ef24c2a
# 🔄 Updating record 0f212dec-2c2f-41df-a07f-27686eb1e830
# 🔄 Updating record 0f214469-9125-448a-bae0-f0e0f5bb5f2e
# 🔄 Updating record 0f36ace7-262e-42ab-bcde-10a6a7f9b294
# 🔄 Updating record 0f3bd518-96d1-4bbc-8aff-18b311790c22
# 🔄 Updating record 0f3fd611-7afa-4bd1-813f-3563995d6e92
# 🔄 Updating record 0f4c9c85-0d91-4830-b69f-4273d67f96bd
# 🔄 Updating record 0f4caf00-ca45-4f36-b489-91cf7fece616
# 🔄 Updating record 0f68b17e-2da9-4fd2-9c23-85b57850c871
# 🔄 Updating record 0f68c02d-38d0-48fc-b370-d1261e50f5be
# 🔄 Updating record 0f693d1f-37b9-487b-b890-655a6cdb81bc
# 🔄 Updating record 0f699e6b-f503-4680-8ee2-cfb867dab134
# 🔄 Updating record 0f6d5111-1e66-4bdc-8f82-5719221cc477
# 🔄 Updating record 0f7e689f-7aa3-4472-9e96-792a10cbf5ce
# 🔄 Updating record 0f7f7a3e-be11-49ae-bd7f-c3040f6341ce
# 🔄 Updating record 0f7fad4e-d932-4776-8025-b5239a90c3c9
# 🔄 Updating record 0f8447a2-6e4b-4b72-bee9-e4b1efc03577
# 🔄 Updating record 0f919489-c500-4f62-816c-40caf00ea71c
# 🔄 Updating record 0f96d634-0eef-4bea-bafa-28ed4b357525
# 🔄 Updating record 12443269-95ae-43de-830b-fda5eabae704
# 🔄 Updating record 124510e7-76d6-4c37-b2e2-2c1c5548e936
# 🔄 Updating record 124ac314-0abb-4ebb-b6f0-6780a1d39477
# 🔄 Updating record 124b1f50-b323-4844-a855-ec622f330eac
# 🔄 Updating record 1258a68a-177e-4726-bdeb-dc3276308f23
# 🔄 Updating record 125da2a4-8a28-4fea-9281-e7bf7a75901d
# 🔄 Updating record 127a2a11-1b69-4676-aaa3-1f3daf7955cf
# 🔄 Updating record 127b4d99-2fd3-479d-ad2a-a61db127d429
# 🔄 Updating record 127d1e8e-72c4-44ee-bc88-055dd5caa0f6
# 🔄 Updating record 12801584-130b-4521-9235-9c2f26f6c723
# 🔄 Updating record 128866a2-87b8-41ae-9ef6-6fc157f493b9
# 🔄 Updating record 1299dde8-1d1a-4cdd-865a-a2ae9d489430
# 🔄 Updating record 129b7feb-a671-49e8-9b5e-02dabbef00fa
# 🔄 Updating record 129d164b-f09a-4dc9-831a-a8d9996c7e5e
# 🔄 Updating record 12a1310b-136c-4f26-8e94-427bcfb2d93c
# 🔄 Updating record 12a1b331-b74a-42b1-bf3e-f7978e105f9a
# 🔄 Updating record 12a78d22-be3b-403e-8218-e874946560da
# 🔄 Updating record 12a9da92-a0ec-44dc-9471-52531184dc5f
# 🔄 Updating record 12ab7810-bd71-4204-9b7d-74c19c92b45c
# 🔄 Updating record 12acc66e-8ffc-473b-bbcb-8c0715df6a49
# 🔄 Updating record 12b3e3b7-5d44-4970-825d-ad3894ace4eb
# 🔄 Updating record 12b720a0-b1d2-4936-bc41-702ae359e5d6
# 🔄 Updating record 12bc619b-33ef-452b-97f8-4cc40abdf574
# 🔄 Updating record 12c3c191-051f-4b27-ac26-4163622b74ba
# 🔄 Updating record 12cf3185-30f5-412e-a42e-b24bd2ad2dd1
# 🔄 Updating record 12d359c4-f835-4c37-8e43-29a35ec27469
# 🔄 Updating record 12db8be6-89a0-484e-93d3-3b6ad2e6ea40
# 🔄 Updating record 12e173ea-860e-4fb4-9fc5-5f9dbe725dca
# 🔄 Updating record 12e2e846-0353-4270-a9c4-b62e2d081f28
# 🔄 Updating record 1303102b-615c-4dde-8a36-f2634959f56e
# 🔄 Updating record 13033848-b866-471b-9842-6da14cc76920
# 🔄 Updating record 1306e746-ea33-462a-804a-b7487e774632
# 🔄 Updating record 130d4aff-5ab9-4fe2-945d-641e6c7e5f93
# 🔄 Updating record 130dccfb-0030-4995-a03b-fc94c2d292e2
# 🔄 Updating record 13100ab9-da80-4dd2-ad46-216f466a9671
# 🔄 Updating record 13124b30-3cad-4a57-949c-06b4001a06c6
# 🔄 Updating record 1313c89a-9886-41c2-8e9a-4f6a455f515f
# 🔄 Updating record 131c54d2-1d4c-446d-8733-7cc6671f32de
# 🔄 Updating record 13200667-5c70-435c-b764-2f6d1efce337
# 🔄 Updating record 13288783-fbc3-40f9-8077-6917b97d817a
# 🔄 Updating record 132b8272-7f1b-42dd-9389-9506d59ae8ed
# 🔄 Updating record 13fe522a-5b2f-4230-bbb6-4c7ecb4261d5
# 🔄 Updating record 1400d6b0-c065-4995-8ab3-5b668a4f3237
# 🔄 Updating record 140998c6-69d7-42e5-9c6a-c7714c952937
# 🔄 Updating record 140a7e55-1181-42ef-905e-30489507bb7b
# 🔄 Updating record 140b62b8-3d5f-4335-adf5-24dd3edcd31d
# 🔄 Updating record 140de123-0556-45ef-b267-566d0108e15c
# 🔄 Updating record 141765ed-fbfd-4424-9925-4ee6d0aefd18
# 🔄 Updating record 141d7eed-afed-4dea-a9af-f0b41e56fb07
# 🔄 Updating record 141f6880-910f-4e6e-8144-fcbcc9523897
# 🔄 Updating record 142a8c36-8bf5-4a77-932c-cabb5f2819fd
# 🔄 Updating record 142b34ba-d5a2-4ace-a38c-08331a3ba43d
# 🔄 Updating record 143b21d2-8d78-49ce-a343-caa2fa2fadef
# 🔄 Updating record 14470e79-bb01-4f67-9984-83178171fa95
# ...
# 🔄 Updating record f92bec6d-443c-499b-be8c-fda717e7c88d
# 🔄 Updating record f946cd9b-6175-4eee-bc4b-c604f1e07805
# 🔄 Updating record f94b4442-1f37-47cf-8c4b-6c36b6c61147
# 🔄 Updating record f94cbda3-aa38-47ab-bea2-8abdcea6a4be
# 🔄 Updating record f94db723-b09a-4389-9596-bc9d19216c31
# 🔄 Updating record f94fdf99-41f7-4184-8a1e-072060becfce
# 🔄 Updating record f950bd63-ee1a-4ec4-a2ee-89da380b2a50
# 🔄 Updating record f95a3cd9-f362-4457-8ef8-a3284db63a2f
# 🔄 Updating record f960ab87-e447-407a-947f-627ba981e8dd
# 🔄 Updating record f96e5aad-bd70-4099-a959-c31c2f3a87c2
# 🔄 Updating record f979e4df-2625-41a3-8511-75195d073bba
# 🔄 Updating record f97a2508-ba0f-41cb-aa18-1fcd6718eadb
# 🔄 Updating record f97d04a7-8a77-4962-a82f-d97d3424f38a
# 🔄 Updating record f981c7ed-7832-4cb4-bb13-36d70f5dc426
# 🔄 Updating record f989c6fd-21db-4249-95e1-6bea7f2ac5ba
# 🔄 Updating record f98bf6bd-0d08-41ee-814b-17ea66049c1a
# 🔄 Updating record f98f9a3e-cef4-4f2f-82e1-e1a1f30a00a5
# 🔄 Updating record f993cdf5-9d2a-48d2-95e2-70d26d5d9a4e
# 🔄 Updating record f9ad4990-6787-4502-b25a-7abad89e2392
# 🔄 Updating record f9bc63d9-0c42-40f9-b08c-ecdd39dbed91
# 🔄 Updating record f9c5088e-b7a5-45e2-bda9-98d12bb9a38c
# 🔄 Updating record f9cd88ad-aed7-45c0-a53b-e47ae6ad0b64
# 🔄 Updating record f9d27b3a-9639-4e5b-afe4-092d284a8ca5
# 🔄 Updating record f9d363f4-cf8e-429e-854f-45c736232858
# 🔄 Updating record f9d87348-ac06-4e93-b3be-deb36d9cae09
# 🔄 Updating record f9f0325e-a095-4465-9661-f0c28df12d7c
# 🔄 Updating record f9f340ff-a155-4556-a483-d2991241bcfc
# 🔄 Updating record f9f9a94c-174e-4026-8f59-ee260ece4fc8
# 🔄 Updating record f9fa568d-7410-4376-8f2f-2548ad332406
# 🔄 Updating record f9fe0f9d-bbfc-4a2a-9dde-84866dab5f50
# 🔄 Updating record fa011c5a-7c7b-41b1-a941-7c1b1362603f
# 🔄 Updating record fa0a298c-40e6-4bb5-a32a-9bbcdfac9cf5
# 🔄 Updating record fa0a903f-93c9-4e53-9316-3a32e5a76525
# 🔄 Updating record fa102a5d-2d88-42a3-8460-77e7cf8ac042
# 🔄 Updating record fa30e18a-5f97-46b5-a224-4be2bbdc7f83
# 🔄 Updating record fa32803c-6ccc-4aac-beb4-c648a80e77ad
# 🔄 Updating record fa368e52-57cf-4a81-84a0-ebc25f736c0e
# 🔄 Updating record fa382a2f-5d3f-4ada-86dc-2cbeeaad1c75
# 🔄 Updating record fa384afe-da28-47ac-a743-53251ae2da28
# 🔄 Updating record fa3f610e-b52b-4a39-8815-12f2093e0e57
# 🔄 Updating record fa42ff1a-d247-4a08-9bef-191bd371af0d
# 🔄 Updating record fa51feea-c744-480c-af87-6e6029e3a6e3
# 🔄 Updating record fa5f2848-0dcc-4f12-8efe-32d9d656f1c7
# 🔄 Updating record fa69ea33-8fad-4494-a67c-43cf37a649d1
# 🔄 Updating record fa6ef716-0b5a-4aad-ab87-bbcb80dd1c45
# 🔄 Updating record fa76ed0d-e015-45e5-9b2c-d457b48bf800
# 🔄 Updating record fa7f3ab9-949b-4f11-aa6f-bf11542be910
# 🔄 Updating record fa829a9c-fbaa-40b1-a1a7-c60478fb94ac
# 🔄 Updating record fa8e342c-c129-4db5-8a7e-3df43f80d4b4
# 🔄 Updating record fa926921-fcd4-46b0-931a-99f82acfc62d
# 🔄 Updating record fa96a3f5-5570-4f3f-93f8-dfdadf7cc6f4
# 🔄 Updating record fa96d20a-6132-4722-921e-2f324aecc892
# 🔄 Updating record faa693ae-dad0-48ee-b085-d8a7484643ed
# 🔄 Updating record faae4b41-246c-4235-9f36-3f710f2a0e25
# 🔄 Updating record fab217bd-99f7-4c9a-9844-f11371e3648b
# 🔄 Updating record fab367b3-6b19-4e8a-8db7-35df84edb647
# 🔄 Updating record fab6cb1c-6604-427c-a667-1478dd17b8f3
# 🔄 Updating record fabb68b3-859d-4be9-9d0c-57cd7bbc01df
# 🔄 Updating record fac02da8-2444-4b14-a83f-ab22f30737ac
# 🔄 Updating record fac74195-d24e-48e0-a432-7e31dcb7b2f5
# 🔄 Updating record fac99246-8777-412c-b142-04b5c5ac1445
# 🔄 Updating record facf827a-2219-466f-9b83-dd8433d66b57
# 🔄 Updating record fad6c0ed-2998-48d7-85af-3cae2f5ffa7a
# 🔄 Updating record fae6fe23-ab6e-4aea-bc13-f460b1f6432a
# 🔄 Updating record faeb778e-f79e-43c3-aaf6-7f4b569559be
# 🔄 Updating record faeecc60-ff74-4151-b629-dc59c5ac627a
# 🔄 Updating record faf4a4c7-43c6-4db6-a88b-6832b511480a
# 🔄 Updating record fafe0683-7122-4543-ab78-724ac5d122b4
# 🔄 Updating record fb00266b-e492-43e7-931f-932fb4b4433c
# 🔄 Updating record fb0f576a-0802-43ea-80e4-3999be93faa5
# 🔄 Updating record fbda43ad-91ad-4f8f-81f8-0c9f8156374f
# 🔄 Updating record fbdf491f-8dd6-4f59-b503-abd221c2d0bd
# 🔄 Updating record fbdf9df8-741b-4606-86f4-031f085d8f1d
# 🔄 Updating record fbe0e171-84bc-44e2-b54a-10025685db34
# 🔄 Updating record fc08383e-d29d-441f-a013-137ae035d9f6
# 🔄 Updating record fc0bc8a0-2e9d-42a8-9e48-da6f19644dda
# 🔄 Updating record fc0f70dd-0e43-474d-b952-796c930e1690
# 🔄 Updating record fc11fcbf-8b58-4ce8-8f42-91bd9fd9ef68
# 🔄 Updating record fc131229-9ab9-4502-a01b-d9988846f441
# 🔄 Updating record fc16f750-a0d8-44c2-8537-5e3ad1fadfe4
# 🔄 Updating record fc1a9934-abea-4caf-bccb-6fdb79d77b3b
# 🔄 Updating record fc22e051-c726-4df5-b440-83b7588f2039
# 🔄 Updating record fc265943-a1d9-4563-9022-28746ed60cbc
# 🔄 Updating record fc323f34-fb4f-4af0-a065-2dd9cda70a48
# 🔄 Updating record fc38400b-ca45-4ce7-8934-04fb7dbfa538
# 🔄 Updating record fc3a8f1a-0d98-43e8-a79d-60598cceb975
# 🔄 Updating record fc3b858c-0014-4fa9-a542-5b8ae0885592
# 🔄 Updating record fc4433ae-045c-4e64-a2d3-e5d638c7de93
# 🔄 Updating record fc46fd46-bc8d-474c-8e33-7a684eb1c2f8
# 🔄 Updating record fc52dd57-8e15-43c2-8c70-7de042a4a74e
# 🔄 Updating record fc5beee9-c007-4302-ac51-fa54c40f4372
# 🔄 Updating record fc5e9d83-2bd5-4078-b727-33c54395890c
# 🔄 Updating record fc5f0aff-8a72-42bc-bd4e-84d0873d9d42
# 🔄 Updating record fc69adea-aac9-4e0c-ae31-2db34a44ba81
# 🔄 Updating record fc6e9d73-31bc-48bb-92e4-184d39d27c29
# 🔄 Updating record fc7014ff-a8e3-4472-b8f5-eb19b9728db3
# 🔄 Updating record fc743230-6c4c-4994-b043-23f7750de0eb
# 🔄 Updating record fc863cd3-58cd-4642-a0c3-c5fccf59d861
# 🔄 Updating record fc885c45-1990-4e5e-b95d-736165c664c8
# 🔄 Updating record fc89f77f-9433-4efd-a294-0d0e11fa3099
# 🔄 Updating record fc8be6bd-990d-4cc1-bd40-7b2a7d79af85
# 🔄 Updating record fcbc30b4-fbaa-41f1-ac18-eba1a78f1b8b
# 🔄 Updating record fcbdb379-b194-45f8-8cef-da5d5c02f70c
# 🔄 Updating record fcc0d704-6c45-4732-92e3-7df327d5036f
# 🔄 Updating record fcc27a92-5b7e-4c72-9d86-f2cccf24bb60
# 🔄 Updating record fcca9e6c-54ce-4a85-9b23-d1a003fe2067
# 🔄 Updating record fccb9757-82f9-49ff-988e-909e64db7299
# 🔄 Updating record fcd145fc-462f-4487-bcf5-13ab0a19cd49
# 🔄 Updating record fcd3cd44-5a88-4625-93f8-cf05ae83e607
# 🔄 Updating record fcedc49c-8b19-4396-878d-4616ba5b7545
# 🔄 Updating record fd018d9d-fba7-4250-8305-8d2829df74db
# 🔄 Updating record fd0bd661-833c-49b6-a92b-f3cb3e09139e
# 🔄 Updating record fd232a42-d261-417c-bb15-04290dffa59b
# 🔄 Updating record fd25caee-09e1-40b9-b646-1924eb8dc206
# 🔄 Updating record fd286134-012a-4ae9-acdd-26168e3bbd13
# 🔄 Updating record fd29cce5-13b9-498d-9dca-f490ab831168
# 🔄 Updating record fd2b8e3c-e39a-410e-89b0-ca09776e6492
# 🔄 Updating record fd2febcf-a36c-4bcb-8cb2-7f805f80c1fd
# 🔄 Updating record fd3756b6-0891-46a8-9bcd-4773d2e2a916
# 🔄 Updating record fd4f7aa8-d3d3-411a-8efc-ee515def46aa
# 🔄 Updating record fd5342b4-3b4f-43ee-9790-b879753061c0
# 🔄 Updating record fd553677-712c-4f20-9a9a-16690f25649d
# 🔄 Updating record fd5716b3-2b5a-49ca-8bf5-4eba7c98d026
# 🔄 Updating record fd609051-59f7-4057-8399-7a76489d9a67
# 🔄 Updating record fd613fe4-226c-4e10-91df-fa55192ef531
# 🔄 Updating record fd63e4f0-fcb5-4028-b85d-0fc7b9696b0b
# 🔄 Updating record fd6d4d09-44ed-4b95-b6c2-3ba46ead38c5
# 🔄 Updating record fd714a63-ca4a-4a46-89c8-3f77f24273e8
# 🔄 Updating record fd754a0e-dda0-438c-9f68-962510e3bd72
# 🔄 Updating record fd7e87a0-f844-42ce-b1d1-3d27d029ced3
# 🔄 Updating record fd7f2281-a589-452c-9f82-3d2d7511fa92
# 🔄 Updating record fd83963c-b830-4e59-acdd-0e66cf883d39
# 🔄 Updating record fd841d7d-0946-49b1-8ab8-d5fc7ed82d53
# 🔄 Updating record fd8b0819-8e23-4fb4-bea8-c1b2b8a9fc8f
# 🔄 Updating record fd8cc47c-e816-4aab-badd-66b048598bf1
# 🔄 Updating record fd8e3cfd-8189-42aa-9e76-b6dcacff397c
# 🔄 Updating record fd8fedb3-4f55-4f71-a77f-736475ce3b51
# 🔄 Updating record fd9b8532-2364-4ef3-a6d8-70779d0e2af6
# 🔄 Updating record fd9d1c95-038b-4faa-ba6e-945516fee96a
# 🔄 Updating record fd9e530a-49e2-4910-925c-dc2e828d9a91
# 🔄 Updating record fda74d8f-307f-4825-be6e-67b212f1cc2e
# 🔄 Updating record fda928a0-c214-4cdb-b6a1-4e64dfd9e26b
# 🔄 Updating record fda9cc07-c26b-43eb-b903-46c94b5ed8a2
# 🔄 Updating record fdad0766-8964-4ba8-8cea-a18ebcc53036
# 🔄 Updating record fdadc62b-e03b-4880-b877-1445f4f25e38
# 🔄 Updating record fdae24d8-cf81-42db-9340-c228a1a989e4
# 🔄 Updating record fdb8834f-ddcc-47e3-b6df-43c49b41b2af
# 🔄 Updating record fdc6d279-c493-41a2-bfc2-3d3236ce1e41
# 🔄 Updating record fdde23fa-0a61-4b71-94a3-c40a8aa7b352
# 🔄 Updating record fde32060-6797-4388-b728-53a0c10774fc
# 🔄 Updating record fdeb059a-d1ed-4930-a3de-52cf6c0e5658
# 🔄 Updating record fdf071ec-98c3-419c-8764-75e62b9b4e50
# 🔄 Updating record fef99898-f058-4fbd-afbb-876f9d3deb4e
# 🔄 Updating record fefaf375-2682-4ba9-9295-06ce45cc8874
# 🔄 Updating record ff016f35-659b-4247-b55b-e336c6e83f97
# 🔄 Updating record ff02491c-4f50-4a60-b84c-91d7eb119e21
# 🔄 Updating record ff02b249-dd42-47d0-ba70-f023afc09e89
# 🔄 Updating record ff0734ca-9edf-4850-b2e8-6760a5c326e6
# 🔄 Updating record ff093b3d-cc00-43ff-b34a-756bb3d77dce
# 🔄 Updating record ff0a5347-cca8-4a9f-960c-987a4a2ca31d
# 🔄 Updating record ff0cccf9-e534-48f4-92c3-f43d3aa3f1a6
# 🔄 Updating record ff0de656-f374-4683-94e3-89c7746d5047
# 🔄 Updating record ff12a1d5-f514-4329-a4a1-2cb0f844f012
# 🔄 Updating record ff1b70ab-e232-4ce4-9277-7ac900d1b52c
# 🔄 Updating record ff1c1c3c-a817-405a-ba4a-eae6779a654a
# 🔄 Updating record ff213e56-be22-4dad-9803-3ed99a62f874
# 🔄 Updating record ff27ef99-5494-4d3d-b0b8-d58d4ddb1a82
# 🔄 Updating record ff314266-f6b9-43b3-82bb-b3dc452041e6
# 🔄 Updating record ff3580ec-7d77-46c1-93df-3dfff91feaba
# 🔄 Updating record ff39c443-b67c-455d-a8d3-6f273aaffc66
# 🔄 Updating record ff4374e8-f84c-491b-8d61-d554d3cece1f
# 🔄 Updating record ff4ad370-c649-442a-aaba-279a6cee7fef
# 🔄 Updating record ff4b04e9-8f0e-413e-85bc-9d172393f07d
# 🔄 Updating record ff58b73b-6a40-4a3d-9afc-01b1d138ebfb
# 🔄 Updating record ff5a3869-f512-474f-b79c-937f7f0ffbc2
# 🔄 Updating record ff63320f-0182-4ec6-92b7-ec9906e5dada
# 🔄 Updating record ff647804-3b56-4d50-b1e3-b40f0bbba33c
# 🔄 Updating record ff69ef5b-be3a-46a0-a844-439f4b6d2d83
# 🔄 Updating record ff6d83d8-87f8-48ea-8274-c49fb8566e6b
# 🔄 Updating record ff6fd7e7-5faa-4f5a-9321-4a4380d19a8a
# 🔄 Updating record ff753fe0-3268-4a6f-ac7b-7a5f047bb752
# 🔄 Updating record ff7b9ad2-00e1-4938-ab31-6a180eb94982
# 🔄 Updating record ff7e142e-ae24-42c2-9c16-fd1422f60f94
# 🔄 Updating record ff7f53b7-4326-4d09-afc5-8c0b50cd3209
# 🔄 Updating record ff8820fd-da13-4c11-8564-728145c80670
# 🔄 Updating record ff88ef3b-7af1-4302-b29b-b248346e289e
# 🔄 Updating record ff91ffa1-b27c-45e9-8924-00d77433e466
# 🔄 Updating record ff981f19-399a-4753-a708-73c4b2c2b504
# 🔄 Updating record ffa46a3e-19dd-4b02-9401-f5d12d2f396c
# 🔄 Updating record ffa97fee-70ee-4ab2-b727-a8698b6a7b47
# 🔄 Updating record ffaad6d1-dad4-4e75-b2cc-7a7eff471767
# 🔄 Updating record ffaf9785-9eb7-4800-b3ea-df67a2e5524a
# 🔄 Updating record ffb10037-6662-40d1-bd70-73b093ae3cb0
# 🔄 Updating record ffb1624d-8d3c-4ec5-aea3-6525e313d53d
# 🔄 Updating record ffb467a7-f835-4fca-9025-fe9b9a44cdd3
# 🔄 Updating record ffb78f96-102d-47cf-be49-7e23ef526db8
# 🔄 Updating record ffba1675-b524-4343-8a8a-c6c3ec37c6cf
# 🔄 Updating record ffbc405a-2b97-4336-baa4-6343a47a2957
# 🔄 Updating record ffbe2772-a643-4522-9dec-27088bdc89c7
# 🔄 Updating record ffc41dfb-3c90-45f5-8690-271384c661de
# 🔄 Updating record ffcb4be6-1de5-4168-97d9-f4adbc276279
# 🔄 Updating record ffcb9053-31cd-4c8e-83f2-ddd1f974b016
# 🔄 Updating record ffccee92-acfd-4725-b1f2-5d644ed61950
# 🔄 Updating record ffd97695-a6f1-46a8-9ff7-a37e3c285980
# 🔄 Updating record ffdb332a-8518-4949-8581-c3d3dbe674fd
# 🔄 Updating record ffe6d8d7-3b4f-44ef-8a2c-e55af1dcdd26
# 🔄 Updating record ffe94bdc-0dbd-4e86-94f0-abf0a7850faf
# ✅ Updated 10900 records so far.
# 🎉 Migration complete. Total records updated: 10900

# %%
from datetime import datetime, timezone

now = datetime.now(timezone.utc)
now_ts = now.timestamp()  # ✅ float

records, _ = client.scroll(
    collection_name=collection_name,
    scroll_filter=models.Filter(
        must=[
            models.FieldCondition(
                key="metadata.expiration_date",
                range=models.Range(gt=now_ts)
            )
        ]
    ),
    with_payload=True
)

print(f"Found {len(records)} documents with expiration_date in the future.")

# %% [markdown]
# ## 5. Check a record

# %%
# usres qdrant id


records = client.retrieve(
    collection_name=collection_name,
    ids=["000bdeac-dc0f-4bdf-84a7-d4adaa4cb327"],
    with_payload=True,
    with_vectors=False
)

metadata = records[0].payload["metadata"]
print("expiration_date:", metadata.get("expiration_date"),
      type(metadata.get("expiration_date")))
records[0].payload["metadata"]

# %%
# uses pdf_id

from qdrant_client.http import models

records = client.scroll(
    collection_name=collection_name,
    with_payload=True,  # change to True to see the payload
    with_vectors=False,  # change to True to see the vectors
    limit=20000, # 👈 dont' forget to set this

    scroll_filter=models.Filter(
        must=[
            models.FieldCondition(
                key="metadata.pdf_id",  # only in upsert>14NOV2024
                match=models.MatchText(
                    text="0aaa5c4d-8f8d-5ea3-8d45-418441a2f6a3"),
            ),
        ]
    ),
)

print(f"Number of points found: {len(records[0])}")
records[0][0].payload["metadata"]

metadata = records[0].payload["metadata"]
print("expiration_date:", metadata.get("expiration_date"),
      type(metadata.get("expiration_date")))

# %%
records[0][0].payload["metadata"]

# %%
for field in ["issue_date", "expiration_date", "upsert_date"]:
    value = records[0][0].payload["metadata"].get(field)
    print(f"{field}: {value} (type: {type(value)})")

# %% [markdown]
# ### Utility to close Qdrant client

# %%
lib.close_qdrant(client)

# %% [markdown]
# ### REFERENCES

# %% [markdown]
# #### How to access diffferent parts of a record
#
# ```python
# all_records  # a tuple
# records = all_records[0]  # records is a list
# records[0].id  # a string
# records[0].payload  # a dict
# records[0].payload["metadata"]  # a dict
# records[0].payload["metadata"]["pdf_id"]  # a string
